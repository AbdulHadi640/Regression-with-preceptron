# %%
import pandas as pd
import numpy as np
# Set a seed so that the results are consistent.
np.random.seed(3)

# %%
adv= pd.read_csv("tvmarketing.csv")
adv.head()
# Out:
#       TV  Sales
# 0  230.1   22.1
# 1   44.5   10.4
# 2   17.2    9.3
# 3  151.5   18.5
# 4  180.8   12.9

# %%
adv_norm = (adv - np.mean(adv))/np.std(adv)
# Out:
# C:\Users\User\AppData\Roaming\Python\Python313\site-packages\numpy\_core\fromnumeric.py:4061: FutureWarning: The behavior of DataFrame.std with axis=None is deprecated, in a future version this will reduce over both axes and return a scalar. To retain the old behavior, pass axis=0 (or do not pass axis)
#   return std(axis=axis, dtype=dtype, out=out, ddof=ddof, **kwargs)

# %%
X_norm = adv_norm['TV']
Y_norm = adv_norm['Sales']

X_norm = np.array(X_norm).reshape((1, len(X_norm)))
Y_norm = np.array(Y_norm).reshape((1, len(Y_norm)))

print ('The shape of X_norm: ' + str(X_norm.shape))
print ('The shape of Y_norm: ' + str(Y_norm.shape))
print ('I have m = %d training examples!' % (X_norm.shape[1]))
# Out:
# The shape of X_norm: (1, 200)
# The shape of Y_norm: (1, 200)
# I have m = 200 training examples!

# %%
X_norm[0,0:5], Y_norm[0,0:5]    
print(np.sum(X_norm))
print(np.sum(Y_norm))
# Out:
# 155.3258266631082
# -2555.9159065710446

# %%
def n_layers(X,Y):

    n_x=X.shape[0]
    n_y=Y.shape[0]
    return (n_x, n_y)

# %%
(n_x, n_y) = n_layers(X_norm,Y_norm)
W = np.random.randn(n_y, n_x) * 0.01
W
# Out:
# array([[0.01788628]])

# %%
def initiliaze_parameters(n_x,n_y):
    W=np.random.randn(n_y,n_x)*0.01
    b=np.zeros((n_y,1))

    parametrs={
        "W": W,
        "b": b
    }
    return parametrs

parameters = initiliaze_parameters(n_x,n_y)
parameters
# Out:
# {'W': array([[0.0043651]]), 'b': array([[0.]])}

# %%
def forward_propagation(X,parameters):
    W=parameters["W"]
    b=parameters["b"]

    Y_hat = np.matmul(W,X) + b
    return Y_hat

Y_hat = forward_propagation(X_norm,parameters)
Y_hat[0,0:5]
# Out:
# array([ 0.00762356, -0.0018366 , -0.0032281 ,  0.00361726,  0.00511071])

# %%
def compute_cost(y,y_hat):
    m=y_hat.shape[1]
    cost= np.sum((y_hat-y)**2)/(2*m)
    return cost


cost = compute_cost(Y_norm, Y_hat)
# Check these for both versions
print("Shape of X_norm:", X_norm.shape)
print("Shape of Y_hat:", Y_hat.shape)
print("Shape of Y_norm:", Y_norm.shape)
print("First 5 values of Y_hat:", Y_hat[0, :5])
# Out:
# Shape of X_norm: (1, 200)
# Shape of Y_hat: (1, 200)
# Shape of Y_norm: (1, 200)
# First 5 values of Y_hat: [ 0.00762356 -0.0018366  -0.0032281   0.00361726  0.00511071]

# %%
def backward_propogation(X,Y,Y_hat):
    m=Y.shape[1]

    dz = Y_hat-Y
    dw = (1/m)*(dz@X.T) 
    db = (1/m)*np.sum(dz, axis=1, keepdims=True)

    grads= {
        "dw"  :dw,
        "db" : db
    }

    return grads

    
grads = backward_propogation(X_norm,Y_norm,Y_hat)

# %%
def update_parametrs( parametrs , grads ,learning_rate =0.01):

    W = parametrs["W"]
    b = parametrs["b"]
    dw = grads["dw"]
    db = grads["db"]

    W = W-learning_rate*dw
    b = b-learning_rate*db

    parametrs = {
        "W": W, 
        "b": b
    }

    return parametrs
parametrs_updated = update_parametrs(parameters,grads,learning_rate=0.01)

# %%
def nn_model(X, Y, learning_rate = 1.2, num_iterations = 1000, print_cost = False):
    n_x = n_layers(X,Y)[0]
    n_y = n_layers(X,Y)[1]
    parameters = initiliaze_parameters(n_x,n_y)
    for i in range(num_iterations):
        y_hat = forward_propagation(X,parameters)
        cost = compute_cost(Y,y_hat)
        grads = backward_propogation(X,Y,y_hat)
        
        parameters = update_parametrs(parameters , grads , learning_rate)
        if print_cost:
            print(f"Cost after iteration {i} is : {cost} ")

    return parameters
        

        
parameters_test = nn_model(X_norm, Y_norm, num_iterations= 100,  print_cost=True)
parameters_test
# Out:
# Cost after iteration 0 is : 82.08858096601244
# Cost after iteration 1 is : 130.38831552853492
# Cost after iteration 2 is : 304.3737158981182
# Cost after iteration 3 is : 739.4516145447476
# Cost after iteration 4 is : 1802.5562411672418
# Cost after iteration 5 is : 4395.581095832796
# Cost after iteration 6 is : 10719.353521423058
# Cost after iteration 7 is : 26141.363544225747
# Cost after iteration 8 is : 63751.53834052423
# Cost after iteration 9 is : 155472.73093502165
# Cost after iteration 10 is : 379156.27325575694
# Cost after iteration 11 is : 924660.81444956
# Cost after iteration 12 is : 2255000.9966811542
# Cost after iteration 13 is : 5499346.124555367
# Cost after iteration 14 is : 13411439.173644803
# Cost after iteration 15 is : 32706925.30414365
# Cost after iteration 16 is : 79763473.135709
# Cost after iteration 17 is : 194521851.27910277
# Cost after iteration 18 is : 474386948.93227446
# Cost after iteration 19 is : 1156903329.4491777
# Cost after iteration 20 is : 2821378869.915398
# Cost after iteration 21 is : 6880591079.16977
# Cost after iteration 22 is : 16779927752.596933
# Cost after iteration 23 is : 40921771421.28773
# Cost after iteration 24 is : 99797293585.11061
# Cost after iteration 25 is : 243379000004.5846
# Cost after iteration 26 is : 593536513019.3174
# Cost after iteration 27 is : 1447477359511.6755
# Cost after iteration 28 is : 3530011482597.6025
# Cost after iteration 29 is : 8608757149386.685
# Cost after iteration 30 is : 20994464188706.414
# Cost after iteration 31 is : 51199902485608.06
# Cost after iteration 32 is : 124862915813109.12
# Cost after iteration 33 is : 304507371859429.7
# Cost after iteration 34 is : 742612319381717.1
# Cost after iteration 35 is : 1811033517940811.8
# Cost after iteration 36 is : 4416628054104729.5
# Cost after iteration 37 is : 1.0770978656697856e+16
# Cost after iteration 38 is : 2.62675461464815e+16
# Cost after iteration 39 is : 6.4059543942042216e+16
# Cost after iteration 40 is : 1.5622415383524938e+17
# Cost after iteration 41 is : 3.8098907266060064e+17
# Cost after iteration 42 is : 9.291308029093837e+17
# Cost after iteration 43 is : 2.2659023863502822e+18
# Cost after iteration 44 is : 5.525931987606965e+18
# Cost after iteration 45 is : 1.3476275286881382e+19
# Cost after iteration 46 is : 3.286504358271285e+19
# Cost after iteration 47 is : 8.014908175295734e+19
# Cost after iteration 48 is : 1.9546224819921525e+20
# Cost after iteration 49 is : 4.766803266549201e+20
# Cost after iteration 50 is : 1.1624962667381903e+21
# Cost after iteration 51 is : 2.835018553552637e+21
# Cost after iteration 52 is : 6.913854632444857e+21
# Cost after iteration 53 is : 1.6861048693553698e+22
# Cost after iteration 54 is : 4.111960377533386e+22
# Cost after iteration 55 is : 1.0027975396849918e+23
# Cost after iteration 56 is : 2.4455559228941256e+23
# Cost after iteration 57 is : 5.964059080042478e+23
# Cost after iteration 58 is : 1.454475049098154e+24
# Cost after iteration 59 is : 3.547076982399729e+24
# Cost after iteration 60 is : 8.6503753549236e+24
# Cost after iteration 61 is : 2.109595989947898e+25
# Cost after iteration 62 is : 5.144742347245299e+25
# Cost after iteration 63 is : 1.2546655352806573e+26
# Cost after iteration 64 is : 3.0597948335818606e+26
# Cost after iteration 65 is : 7.462024069641773e+26
# Cost after iteration 66 is : 1.8197887846856332e+27
# Cost after iteration 67 is : 4.4379798161473847e+27
# Cost after iteration 68 is : 1.0823049913418373e+28
# Cost after iteration 69 is : 2.639453406303086e+28
# Cost after iteration 70 is : 6.4369233624319315e+28
# Cost after iteration 71 is : 1.5697940442849458e+29
# Cost after iteration 72 is : 3.828309275600055e+29
# Cost after iteration 73 is : 9.336225960980334e+29
# Cost after iteration 74 is : 2.276856672736316e+30
# Cost after iteration 75 is : 5.552646572448145e+30
# Cost after iteration 76 is : 1.3541425039050223e+31
# Cost after iteration 77 is : 3.3023926463839243e+31
# Cost after iteration 78 is : 8.053655475284844e+31
# Cost after iteration 79 is : 1.964071915724736e+32
# Cost after iteration 80 is : 4.789847916858154e+32
# Cost after iteration 81 is : 1.1681162427377111e+33
# Cost after iteration 82 is : 2.848724177118954e+33
# Cost after iteration 83 is : 6.947278995352735e+33
# Cost after iteration 84 is : 1.6942561806064929e+34
# Cost after iteration 85 is : 4.1318392530996306e+34
# Cost after iteration 86 is : 1.007645467602404e+35
# Cost after iteration 87 is : 2.457378726962746e+35
# Cost after iteration 88 is : 5.992891748024808e+35
# Cost after iteration 89 is : 1.4615065683397323e+36
# Cost after iteration 90 is : 3.5642249837137184e+36
# Cost after iteration 91 is : 8.692194759658469e+36
# Cost after iteration 92 is : 2.1197946281469286e+37
# Cost after iteration 93 is : 5.1696141075618715e+37
# Cost after iteration 94 is : 1.2607310947129327e+38
# Cost after iteration 95 is : 3.0745871163789723e+38
# Cost after iteration 96 is : 7.498098504785445e+38
# Cost after iteration 97 is : 1.8285863779224877e+39
# Cost after iteration 98 is : 4.459434801222797e+39
# Cost after iteration 99 is : 1.0875372903603677e+40
# {'W': array([[1.30083135e+20]]), 'b': array([[8.90332427e+19]])}

# %%
def predict(X, Y, parameters, X_pred):
    
    # Retrieve each parameter from the dictionary "parameters".
    W = parameters["W"]
    b = parameters["b"]
    
    # Use the same mean and standard deviation of the original training array X.
    if isinstance(X, pd.Series):
        X_mean = np.mean(X)
        X_std = np.std(X)
        X_pred_norm = ((X_pred - X_mean)/X_std).reshape((1, len(X_pred)))
    else:
        X_mean = np.array(np.mean(X)).reshape((len(X.axes[1]),1))
        X_std = np.array(np.std(X)).reshape((len(X.axes[1]),1))
        X_pred_norm = ((X_pred - X_mean)/X_std)
    # Make predictions.
    Y_pred_norm = np.matmul(W, X_pred_norm) + b
    # Use the same mean and standard deviation of the original training array Y.
    Y_pred = Y_pred_norm * np.std(Y) + np.mean(Y)
    
    return Y_pred[0]

X_pred = np.array([50, 120, 280])
Y_pred = predict(adv["TV"], adv["Sales"], parameters_test, X_pred)
print(f"TV marketing expenses:\n{X_pred}")
print(f"Predictions of sales:\n{Y_pred}")
# Out:
# TV marketing expenses:
# [ 50 120 280]
# Predictions of sales:
# [-60.26223638 -56.93467155 -49.32880908]

# %%
import matplotlib.pyplot as plt

# .flatten() or .T ensures we are plotting a 1D sequence of 200 values
x_plot = X_norm.flatten()
y_true = Y_norm.flatten()
y_pred = Y_hat.flatten()

plt.figure(figsize=(10, 6))
plt.scatter(x_plot, y_true, color='blue', alpha=0.5, label='Actual Data')
plt.scatter(x_plot, y_pred, color='red', s=10, label='Model Prediction')
plt.title("Actual vs. Predicted Data")
plt.xlabel("Input (X_norm)")
plt.ylabel("Output (Y_norm)")
plt.legend()
plt.show()

# %%
df = pd.read_csv('train.csv')
X_multi = df[['GrLivArea', 'OverallQual']]
Y_multi = df['SalePrice']

# %%
display(X_multi)
display(Y_multi)
# Out:
#       GrLivArea  OverallQual
# 0          1710            7
# 1          1262            6
# 2          1786            7
# 3          1717            7
# 4          2198            8
# ...         ...          ...
# 1455       1647            6
# 1456       2073            6
# 1457       2340            7
# 1458       1078            5
# 1459       1256            5
#
# [1460 rows x 2 columns]
# 0       208500
# 1       181500
# 2       223500
# 3       140000
# 4       250000
#          ...
# 1455    175000
# 1456    210000
# 1457    266500
# 1458    142125
# 1459    147500
# Name: SalePrice, Length: 1460, dtype: int64

# %%
X_multi_norm = (X_multi - np.mean(X_multi))/np.std(X_multi)
Y_multi_norm = (Y_multi - np.mean(Y_multi))/np.std(Y_multi)
# Out:
# C:\Users\User\AppData\Roaming\Python\Python313\site-packages\numpy\_core\fromnumeric.py:4061: FutureWarning: The behavior of DataFrame.std with axis=None is deprecated, in a future version this will reduce over both axes and return a scalar. To retain the old behavior, pass axis=0 (or do not pass axis)
#   return std(axis=axis, dtype=dtype, out=out, ddof=ddof, **kwargs)

# %%
X_multi_norm = np.array(X_multi_norm).T
Y_multi_norm = np.array(Y_multi_norm).reshape((1, len(Y_multi_norm)))

print ('The shape of X: ' + str(X_multi_norm.shape))
print ('The shape of Y: ' + str(Y_multi_norm.shape))
print ('I have m = %d training examples!' % (X_multi_norm.shape[1]))
# Out:
# The shape of X: (2, 1460)
# The shape of Y: (1, 1460)
# I have m = 1460 training examples!

# %%
parameters_multi = nn_model(X_multi_norm, Y_multi_norm, num_iterations=100, print_cost=True)

print("W = " + str(parameters_multi["W"]))
print("b = " + str(parameters_multi["b"]))

W_multi = parameters_multi["W"]
b_multi = parameters_multi["b"]
# Out:
# Cost after iteration 0 is : 8.779702441485478
# Cost after iteration 1 is : 1058445917979.2007
# Cost after iteration 2 is : 1.3533425165846472e+23
# Cost after iteration 3 is : 1.7304010871834673e+34
# Cost after iteration 4 is : 2.2125130082236957e+45
# Cost after iteration 5 is : 2.828947489582831e+56
# Cost after iteration 6 is : 3.617128518146938e+67
# Cost after iteration 7 is : 4.6249068832031246e+78
# Cost after iteration 8 is : 5.913465217226433e+89
# Cost after iteration 9 is : 7.561032418263058e+100
# Cost after iteration 10 is : 9.667632957996622e+111
# Cost after iteration 11 is : 1.2361159407912318e+123
# Cost after iteration 12 is : 1.5805136849080701e+134
# Cost after iteration 13 is : 2.0208650546021692e+145
# Cost after iteration 14 is : 2.5839039597747977e+156
# Cost after iteration 15 is : 3.30381272026808e+167
# Cost after iteration 16 is : 4.224297288339027e+178
# Cost after iteration 17 is : 5.401240654712564e+189
# Cost after iteration 18 is : 6.906095527568973e+200
# Cost after iteration 19 is : 8.830222255380355e+211
# Cost after iteration 20 is : 1.1290435350647652e+223
# Cost after iteration 21 is : 1.4436095346239248e+234
# Cost after iteration 22 is : 1.845817653380003e+245
# Cost after iteration 23 is : 2.3600861090300482e+256
# Cost after iteration 24 is : 3.017636347684166e+267
# Cost after iteration 25 is : 3.858388510496794e+278
# Cost after iteration 26 is : 4.933385001595237e+289
# Cost after iteration 27 is : 6.307889293095342e+300
# Cost after iteration 28 is : inf
# Cost after iteration 29 is : inf
# Cost after iteration 30 is : inf
# Cost after iteration 31 is : inf
# Cost after iteration 32 is : inf
# Cost after iteration 33 is : inf
# Cost after iteration 34 is : inf
# Cost after iteration 35 is : inf
# Cost after iteration 36 is : inf
# Cost after iteration 37 is : inf
# Cost after iteration 38 is : inf
# Cost after iteration 39 is : inf
# Cost after iteration 40 is : inf
# Cost after iteration 41 is : inf
# Cost after iteration 42 is : inf
# Cost after iteration 43 is : inf
# Cost after iteration 44 is : inf
# Cost after iteration 45 is : inf
# Cost after iteration 46 is : inf
# Cost after iteration 47 is : inf
# Cost after iteration 48 is : inf
# Cost after iteration 49 is : inf
# Cost after iteration 50 is : inf
# Cost after iteration 51 is : inf
# Cost after iteration 52 is : inf
# Cost after iteration 53 is : inf
# Cost after iteration 54 is : inf
# Cost after iteration 55 is : inf
# Cost after iteration 56 is : nan
# Cost after iteration 57 is : nan
# Cost after iteration 58 is : nan
# Cost after iteration 59 is : nan
# Cost after iteration 60 is : nan
# Cost after iteration 61 is : nan
# Cost after iteration 62 is : nan
# Cost after iteration 63 is : nan
# Cost after iteration 64 is : nan
# Cost after iteration 65 is : nan
# Cost after iteration 66 is : nan
# Cost after iteration 67 is : nan
# Cost after iteration 68 is : nan
# Cost after iteration 69 is : nan
# Cost after iteration 70 is : nan
# Cost after iteration 71 is : nan
# Cost after iteration 72 is : nan
# Cost after iteration 73 is : nan
# Cost after iteration 74 is : nan
# Cost after iteration 75 is : nan
# Cost after iteration 76 is : nan
# Cost after iteration 77 is : nan
# Cost after iteration 78 is : nan
# Cost after iteration 79 is : nan
# Cost after iteration 80 is : nan
# Cost after iteration 81 is : nan
# Cost after iteration 82 is : nan
# Cost after iteration 83 is : nan
# Cost after iteration 84 is : nan
# Cost after iteration 85 is : nan
# Cost after iteration 86 is : nan
# Cost after iteration 87 is : nan
# Cost after iteration 88 is : nan
# Cost after iteration 89 is : nan
# Cost after iteration 90 is : nan
# Cost after iteration 91 is : nan
# Cost after iteration 92 is : nan
# Cost after iteration 93 is : nan
# Cost after iteration 94 is : nan
# Cost after iteration 95 is : nan
# Cost after iteration 96 is : nan
# Cost after iteration 97 is : nan
# Cost after iteration 98 is : nan
# Cost after iteration 99 is : nan
# W = [[nan nan]]
# b = [[nan]]
# C:\Users\User\AppData\Local\Temp\ipykernel_14636\684658422.py:3: RuntimeWarning: overflow encountered in square
#   cost= np.sum((y_hat-y)**2)/(2*m)
# C:\Users\User\AppData\Local\Temp\ipykernel_14636\1654207973.py:5: RuntimeWarning: overflow encountered in matmul
#   dw = (1/m)*(dz@X.T)
# C:\Users\User\AppData\Roaming\Python\Python313\site-packages\numpy\_core\fromnumeric.py:86: RuntimeWarning: overflow encountered in reduce
#   return ufunc.reduce(obj, axis, dtype, out, **passkwargs)
# C:\Users\User\AppData\Local\Temp\ipykernel_14636\3365932824.py:5: RuntimeWarning: invalid value encountered in matmul
#   Y_hat = np.matmul(W,X) + b
